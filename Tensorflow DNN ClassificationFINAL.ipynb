# %% [markdown]
# # Tensorflow Deep Neural Network Classification
# ## Predicting Dietary Guidelines based on Food Consumption
#
# ### Author: Nick Rosso

# %%
"""
=======
Predicting Dietary Guidelines Based on food factors
Author: Nick Rosso

"""
print (__doc__)
# Out:
# =======
# Predicting Dietary Guidelines Based on food factors
# Author: Nick Rosso

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from collections import defaultdict
from sklearn.model_selection import KFold

import pandas_ml as pdml
import pandas
import numpy as np
import tensorflow as tf
import csv



#dataset for predicting Sugar, Fat, SatFat, Salt 
filename = "tensorflowDataset-Complete.csv"
#dataset for predicting fruits and vegies
removed_Unknowns = "tensorflowDataset-FruitsVeg.csv"

# %%
#Loads Headers into an Array
#f = open(filename, 'r', newline='', encoding='utf8')
#row = f.readline()
#guideline = row.split(',')
#headers is a list of guidelines
headers = ["GDLINES_PortionFruitsVeg", "GDLINES_FreeSugars", "GDLINES_Salt", "GDLINES_Fat", "GDLINES_SatFat"]

# %%
#Drops columns other than the one passed into function x is the guideline index to be stored.

def keep_Guideline(dataframe,x):
    """
        Input: pandas dataframe
        Output: dataframe with all other columns EXCEPT for 'X'
        
        This function uses a list of boolean to loop over the guidelines and remove all of the guidelines except
        for the true boolean 'X'.
    """
    for i in range(0, 5):
        if i==x:
            continue
        dataframe = dataframe.drop(headers[i], 1)

    return dataframe

# %%
#smotes the filename given. 
#x is the index of the guideline to use as the target to smote.

def SMOTE_Dataset(filename,x):
    target=headers[x]
    """
        Input: input data path for the specified csv file.In this case-> tensorflowDataset-Complete.csv
        Output:dataframe with balanced classes.
        
        This function reads the input from the csv file, using the headers stored in the file, and using a , as the seperator.
        Then it balances the classes of the dataframe using SMOTE that is built into pandas_ml
    """
    
    df = pandas.read_csv(filename, sep=',', header=0)
    df = pdml.ModelFrame(df.to_dict(orient='list'),target=target)
    
    #Fruits and vegies dataset is different than the others so nothing needs to be dropped
    #invokes keep_guideline to remove the uneeded guidelines.
    if headers[x] != "GDLINES_PortionFruitsVeg":
        df = keep_Guideline(df,x)
    
    print("%s has a class count of:\n%s" % (target, df.target.value_counts()))
    
    #applies SMOTE to the dataframe
    sampler = df.imbalance.over_sampling.SMOTE()
    sampled = df.fit_sample(sampler)
    print("%s has a class count of:\n%s" % (target, sampled.target.value_counts()))
    #rounds SMOTED Data to 0 or 1
    sampled = sampled.round(0)
    
    return sampled

# %%
def ten_Fold_Cross_validation(dataframe, no_folds, guideline, hidden_layer_array):
    """
        Input: SMOTED dataframe, amount of folds, guideline index 0-5, and an array of hidden layer configuration.
        output: DNN classifier accuracy of the 10 fold cross validation on the 10 tests.
        
        This function performs k fold cross validation on a DNN using Proximal adaptive gradient Optimization.
        Note: dimensions must be set to the number of real valued columns to use in training.
    """
    #converts dataframe to numpy array 
    dataframe = dataframe.as_matrix()
    
    kf = KFold(n_splits = no_folds, shuffle=True)
    print("Splitting data: %s times" % (kf.get_n_splits(dataframe)))
    print(kf)
    
    
    accuracy_list = []
    for train, test in kf.split(dataframe):
        
        trainX = []
        trainY = []
        testX = []
        testY = []
        
        columns = [i ++1 for i in range(1,3913)]
        for index in train:
            #appends columns 1-3914 incremeneting by 1. column 0 must be ignored as its the target
            trainX.append(dataframe[index,columns])
            #Stores the first column of the selected index to trainY
            trainY.append(dataframe[index,0])

        

        for index in test:
            #appends columns 1-3914 incremeneting by 1. Column 0 must be ignored as its the target
            testX.append(dataframe[index, columns])
            #Stores the first column of the selected index to testY
            testY.append(dataframe[index,0])
        
        #Converts to np array to apply feature datatype so it can be used by DNN classifer.
        trainX = np.asarray(trainX, dtype = np.bool_)
        trainY = np.asarray(trainY, dtype = np.bool_)
        testX = np.asarray(testX, dtype = np.bool_)
        testY = np.asarray(testY, dtype = np.bool_)
        
        feature_columns = [tf.contrib.layers.real_valued_column("", dimension=3913)]

        classifier = tf.contrib.learn.DNNClassifier(feature_columns=feature_columns, hidden_units= hidden_layer_array,
                                                    n_classes = 2,
                                                    #model_dir="/tmp/FruitsVegies/8-7-2017-109",
                                                    optimizer=tf.train.ProximalAdagradOptimizer(learning_rate=0.1,
                                                                                                l1_regularization_strength=0.001),
                                                    enable_centered_bias=None)
    

        
        classifier.fit(x=trainX, y=trainY, steps=1000)

        accuracy_score = classifier.evaluate(x=testX,y=testY)["accuracy"]
        print('Accuracy: {0:f}'.format(accuracy_score))

        accuracy_list.append(accuracy_score)
        
    return accuracy_list

# %% [markdown]
# ### Driving Script:

# %%
#list of accuracies for each network configuration
accuracy_dict = defaultdict(list)
#list of arrays to test the network on.
hidden_layer_parameters = [[64,32]]



for test in range(len(hidden_layer_parameters)):
    #0 - 5 guidelines that we are testing
    for index in range(0,5):
        #Seperate dataset for predicting fruits and vegies. It contains Unknowns that needed to be removed
        print("Performing test on %s with hidden layers: %s------------------------------------------" % (headers[index],hidden_layer_parameters[test]))
        
        if index == 0:
            smoted_Df = SMOTE_Dataset(removed_Unknowns, index)
            #stores list of accuracy to be added to the accuracy dictionary
            results = ten_Fold_Cross_validation(smoted_Df, 10, index, hidden_layer_parameters[test])
            print("TEST %s DONE ----------------------------------------------------------------------" % (index+1))
            
            for value in results:
                #stores results as key in format GDLINE-10,20,10
                #joins two index's together to form the key in the dict
                dict_key = ("%s-%s" % (headers[index], hidden_layer_parameters[test]))
                accuracy_dict[dict_key].append(value)
                
        #uses other file that is not altered from having the unknowns in the dataset.
        else:
            smoted_Df = SMOTE_Dataset(filename, index)
            results = ten_Fold_Cross_validation(smoted_Df, 10, index, hidden_layer_parameters[test])
            print("TEST %s DONE -----------------------------------------------------------------------" % (index+1))
            
            
            for value in results:
                #stores results as key in format GDLINE10,20
                #hidden_layer_string = "".join(str(hidden_layer_parameters[test]))
                #joins two index's together to form the key in the dict
                dict_key = ("%s-%s" % (headers[index], hidden_layer_parameters[test]))

                accuracy_dict[dict_key].append(value)

    print("Tests Done!")
# Out:
# Performing test on GDLINES_PortionFruitsVeg with hidden layers: [64, 32]------------------------------------------
# GDLINES_PortionFruitsVeg has a class count of:
# 0    2311
# 1     656
# Name: GDLINES_PortionFruitsVeg, dtype: int64
# GDLINES_PortionFruitsVeg has a class count of:
# 1    2311
# 0    2311
# Name: GDLINES_PortionFruitsVeg, dtype: int64
# Splitting data: 10 times
# KFold(n_splits=10, random_state=None, shuffle=True)
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Nick\AppData\Local\Temp\tmpkyarj0kt
# INFO:tensorflow:Using config: {'_session_config': None, '_environment': 'local', '_num_worker_replicas': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x00000000138F4DD8>, '_master': '', '_save_checkpoints_secs': 600, '_tf_random_seed': None, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_num_ps_replicas': 0, '_task_id': 0, '_is_chief': True, '_model_dir': 'C:\\Users\\Nick\\AppData\\Local\\Temp\\tmpkyarj0kt', '_keep_checkpoint_every_n_hours': 10000, '_task_type': None, '_keep_checkpoint_max': 5}
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:57: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:57: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From f:\anaconda\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\Nick\AppData\Local\Temp\tmpkyarj0kt\model.ckpt.
# INFO:tensorflow:loss = 0.693483, step = 1
# INFO:tensorflow:global_step/sec: 6.89966
# INFO:tensorflow:loss = 0.367074, step = 101 (14.493 sec)
# INFO:tensorflow:global_step/sec: 7.51431
# INFO:tensorflow:loss = 0.253554, step = 201 (13.324 sec)
# INFO:tensorflow:global_step/sec: 7.54649
# INFO:tensorflow:loss = 0.170234, step = 301 (13.251 sec)
# INFO:tensorflow:global_step/sec: 7.63318
# INFO:tensorflow:loss = 0.0870787, step = 401 (13.090 sec)
# INFO:tensorflow:global_step/sec: 7.44006
# INFO:tensorflow:loss = 0.0577821, step = 501 (13.441 sec)
# INFO:tensorflow:global_step/sec: 7.30796
# INFO:tensorflow:loss = 0.0962794, step = 601 (13.688 sec)
# INFO:tensorflow:global_step/sec: 7.28357
# INFO:tensorflow:loss = 0.0389891, step = 701 (13.726 sec)
# INFO:tensorflow:global_step/sec: 7.19821
# INFO:tensorflow:loss = 0.037309, step = 801 (13.887 sec)
# INFO:tensorflow:global_step/sec: 7.69122
# INFO:tensorflow:loss = 0.13821, step = 901 (13.033 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\Nick\AppData\Local\Temp\tmpkyarj0kt\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0302012.
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:59: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:59: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From f:\anaconda\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-09-12-19:14:27
# INFO:tensorflow:Restoring parameters from C:\Users\Nick\AppData\Local\Temp\tmpkyarj0kt\model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-09-12-19:14:29
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.904968, accuracy/baseline_label_mean = 0.509719, accuracy/threshold_0.500000_mean = 0.904968, auc = 0.944579, auc_precision_recall = 0.921794, global_step = 1000, labels/actual_label_mean = 0.509719, labels/prediction_mean = 0.545279, loss = 0.336649, precision/positive_threshold_0.500000_mean = 0.872093, recall/positive_threshold_0.500000_mean = 0.95339
# Accuracy: 0.904968
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Nick\AppData\Local\Temp\tmpd8qs2mh9
# INFO:tensorflow:Using config: {'_session_config': None, '_environment': 'local', '_num_worker_replicas': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x00000000178C3160>, '_master': '', '_save_checkpoints_secs': 600, '_tf_random_seed': None, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_num_ps_replicas': 0, '_task_id': 0, '_is_chief': True, '_model_dir': 'C:\\Users\\Nick\\AppData\\Local\\Temp\\tmpd8qs2mh9', '_keep_checkpoint_every_n_hours': 10000, '_task_type': None, '_keep_checkpoint_max': 5}
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:57: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:57: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From f:\anaconda\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\Nick\AppData\Local\Temp\tmpd8qs2mh9\model.ckpt.
# INFO:tensorflow:loss = 0.693962, step = 1
# INFO:tensorflow:global_step/sec: 6.74553
# INFO:tensorflow:loss = 0.374606, step = 101 (14.815 sec)
# INFO:tensorflow:global_step/sec: 7.34413
# INFO:tensorflow:loss = 0.279715, step = 201 (13.610 sec)
# INFO:tensorflow:global_step/sec: 7.47332
# INFO:tensorflow:loss = 0.192271, step = 301 (13.381 sec)
# INFO:tensorflow:global_step/sec: 7.36101
# INFO:tensorflow:loss = 0.128187, step = 401 (13.585 sec)
# INFO:tensorflow:global_step/sec: 7.45982
# INFO:tensorflow:loss = 0.0749103, step = 501 (13.410 sec)
# INFO:tensorflow:global_step/sec: 7.64445
# INFO:tensorflow:loss = 0.0575531, step = 601 (13.092 sec)
# INFO:tensorflow:global_step/sec: 7.51632
# INFO:tensorflow:loss = 0.0485711, step = 701 (13.304 sec)
# INFO:tensorflow:global_step/sec: 7.65039
# INFO:tensorflow:loss = 0.0440161, step = 801 (13.071 sec)
# INFO:tensorflow:global_step/sec: 7.4204
# INFO:tensorflow:loss = 0.0396099, step = 901 (13.503 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\Nick\AppData\Local\Temp\tmpd8qs2mh9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0377274.
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:59: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:59: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From f:\anaconda\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-09-12-19:17:01
# INFO:tensorflow:Restoring parameters from C:\Users\Nick\AppData\Local\Temp\tmpd8qs2mh9\model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-09-12-19:17:02
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.902808, accuracy/baseline_label_mean = 0.481641, accuracy/threshold_0.500000_mean = 0.902808, auc = 0.936837, auc_precision_recall = 0.900184, global_step = 1000, labels/actual_label_mean = 0.481641, labels/prediction_mean = 0.530645, loss = 0.352245, precision/positive_threshold_0.500000_mean = 0.856, recall/positive_threshold_0.500000_mean = 0.959641
# Accuracy: 0.902808
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Nick\AppData\Local\Temp\tmp9lf_264s
# INFO:tensorflow:Using config: {'_session_config': None, '_environment': 'local', '_num_worker_replicas': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x00000000172D2048>, '_master': '', '_save_checkpoints_secs': 600, '_tf_random_seed': None, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_num_ps_replicas': 0, '_task_id': 0, '_is_chief': True, '_model_dir': 'C:\\Users\\Nick\\AppData\\Local\\Temp\\tmp9lf_264s', '_keep_checkpoint_every_n_hours': 10000, '_task_type': None, '_keep_checkpoint_max': 5}
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:57: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:57: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From f:\anaconda\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\Nick\AppData\Local\Temp\tmp9lf_264s\model.ckpt.
# INFO:tensorflow:loss = 0.698684, step = 1
# INFO:tensorflow:global_step/sec: 6.68686
# INFO:tensorflow:loss = 0.379384, step = 101 (14.961 sec)
# INFO:tensorflow:global_step/sec: 7.15918
# INFO:tensorflow:loss = 0.28802, step = 201 (13.960 sec)
# INFO:tensorflow:global_step/sec: 7.56136
# INFO:tensorflow:loss = 0.222499, step = 301 (13.233 sec)
# INFO:tensorflow:global_step/sec: 7.69419
# INFO:tensorflow:loss = 0.162576, step = 401 (12.981 sec)
# INFO:tensorflow:global_step/sec: 7.57609
# INFO:tensorflow:loss = 0.090307, step = 501 (13.204 sec)
# INFO:tensorflow:global_step/sec: 7.25168
# INFO:tensorflow:loss = 0.0611989, step = 601 (13.790 sec)
# INFO:tensorflow:global_step/sec: 7.21315
# INFO:tensorflow:loss = 0.768917, step = 701 (13.859 sec)
# INFO:tensorflow:global_step/sec: 7.55781
# INFO:tensorflow:loss = 0.0423865, step = 801 (13.247 sec)
# INFO:tensorflow:global_step/sec: 7.51848
# INFO:tensorflow:loss = 0.0433652, step = 901 (13.316 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\Nick\AppData\Local\Temp\tmp9lf_264s\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.038209.
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:59: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:59: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From f:\anaconda\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-09-12-19:19:39
# INFO:tensorflow:Restoring parameters from C:\Users\Nick\AppData\Local\Temp\tmp9lf_264s\model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-09-12-19:19:41
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.91342, accuracy/baseline_label_mean = 0.497835, accuracy/threshold_0.500000_mean = 0.91342, auc = 0.950722, auc_precision_recall = 0.924832, global_step = 1000, labels/actual_label_mean = 0.497835, labels/prediction_mean = 0.538559, loss = 0.292876, precision/positive_threshold_0.500000_mean = 0.876984, recall/positive_threshold_0.500000_mean = 0.96087
# Accuracy: 0.913420
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Nick\AppData\Local\Temp\tmpt0eizbo9
# INFO:tensorflow:Using config: {'_session_config': None, '_environment': 'local', '_num_worker_replicas': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000000016DC6198>, '_master': '', '_save_checkpoints_secs': 600, '_tf_random_seed': None, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_num_ps_replicas': 0, '_task_id': 0, '_is_chief': True, '_model_dir': 'C:\\Users\\Nick\\AppData\\Local\\Temp\\tmpt0eizbo9', '_keep_checkpoint_every_n_hours': 10000, '_task_type': None, '_keep_checkpoint_max': 5}
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:57: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:57: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From f:\anaconda\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\Nick\AppData\Local\Temp\tmpt0eizbo9\model.ckpt.
# INFO:tensorflow:loss = 0.698014, step = 1
# INFO:tensorflow:global_step/sec: 7.41046
# INFO:tensorflow:loss = 0.379996, step = 101 (13.484 sec)
# INFO:tensorflow:global_step/sec: 7.48487
# INFO:tensorflow:loss = 0.265508, step = 201 (13.355 sec)
# INFO:tensorflow:global_step/sec: 7.46983
# INFO:tensorflow:loss = 0.179671, step = 301 (13.392 sec)
# INFO:tensorflow:global_step/sec: 7.33573
# INFO:tensorflow:loss = 0.125401, step = 401 (13.632 sec)
# INFO:tensorflow:global_step/sec: 7.30415
# INFO:tensorflow:loss = 0.0588272, step = 501 (13.686 sec)
# INFO:tensorflow:global_step/sec: 7.21871
# INFO:tensorflow:loss = 0.0427689, step = 601 (13.853 sec)
# INFO:tensorflow:global_step/sec: 7.67161
# INFO:tensorflow:loss = 0.0373062, step = 701 (13.035 sec)
# INFO:tensorflow:global_step/sec: 7.67682
# INFO:tensorflow:loss = 0.0334134, step = 801 (13.026 sec)
# INFO:tensorflow:global_step/sec: 7.69395
# INFO:tensorflow:loss = 0.0309982, step = 901 (13.044 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\Nick\AppData\Local\Temp\tmpt0eizbo9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.029637.
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:59: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:59: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From f:\anaconda\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-09-12-19:22:15
# INFO:tensorflow:Restoring parameters from C:\Users\Nick\AppData\Local\Temp\tmpt0eizbo9\model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-09-12-19:22:16
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.917749, accuracy/baseline_label_mean = 0.487013, accuracy/threshold_0.500000_mean = 0.917749, auc = 0.947323, auc_precision_recall = 0.933624, global_step = 1000, labels/actual_label_mean = 0.487013, labels/prediction_mean = 0.528047, loss = 0.319964, precision/positive_threshold_0.500000_mean = 0.881633, recall/positive_threshold_0.500000_mean = 0.96
# Accuracy: 0.917749
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Nick\AppData\Local\Temp\tmprcvenrcn
# INFO:tensorflow:Using config: {'_session_config': None, '_environment': 'local', '_num_worker_replicas': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000000018F5D7F0>, '_master': '', '_save_checkpoints_secs': 600, '_tf_random_seed': None, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_num_ps_replicas': 0, '_task_id': 0, '_is_chief': True, '_model_dir': 'C:\\Users\\Nick\\AppData\\Local\\Temp\\tmprcvenrcn', '_keep_checkpoint_every_n_hours': 10000, '_task_type': None, '_keep_checkpoint_max': 5}
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:57: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:57: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From f:\anaconda\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\Nick\AppData\Local\Temp\tmprcvenrcn\model.ckpt.
# INFO:tensorflow:loss = 0.697056, step = 1
# INFO:tensorflow:global_step/sec: 6.90664
# INFO:tensorflow:loss = 0.365971, step = 101 (14.479 sec)
# INFO:tensorflow:global_step/sec: 7.61015
# INFO:tensorflow:loss = 0.255073, step = 201 (13.130 sec)
# INFO:tensorflow:global_step/sec: 7.23547
# INFO:tensorflow:loss = 0.16775, step = 301 (13.816 sec)
# INFO:tensorflow:global_step/sec: 7.56026
# INFO:tensorflow:loss = 0.0927327, step = 401 (13.227 sec)
# INFO:tensorflow:global_step/sec: 7.40192
# INFO:tensorflow:loss = 0.0634074, step = 501 (13.510 sec)
# INFO:tensorflow:global_step/sec: 7.22214
# INFO:tensorflow:loss = 0.0507145, step = 601 (13.851 sec)
# INFO:tensorflow:global_step/sec: 7.42266
# INFO:tensorflow:loss = 0.0411399, step = 701 (13.467 sec)
# INFO:tensorflow:global_step/sec: 7.11187
# INFO:tensorflow:loss = 0.0369628, step = 801 (14.061 sec)
# INFO:tensorflow:global_step/sec: 7.52648
# INFO:tensorflow:loss = 0.0350308, step = 901 (13.320 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\Nick\AppData\Local\Temp\tmprcvenrcn\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0326647.
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:59: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:59: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From f:\anaconda\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-09-12-19:24:54
# INFO:tensorflow:Restoring parameters from C:\Users\Nick\AppData\Local\Temp\tmprcvenrcn\model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-09-12-19:24:56
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.911255, accuracy/baseline_label_mean = 0.528139, accuracy/threshold_0.500000_mean = 0.911255, auc = 0.960737, auc_precision_recall = 0.952237, global_step = 1000, labels/actual_label_mean = 0.528139, labels/prediction_mean = 0.552233, loss = 0.273079, precision/positive_threshold_0.500000_mean = 0.891892, recall/positive_threshold_0.500000_mean = 0.946721
# Accuracy: 0.911255
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Nick\AppData\Local\Temp\tmp0zfs791q
# INFO:tensorflow:Using config: {'_session_config': None, '_environment': 'local', '_num_worker_replicas': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x00000000182D6160>, '_master': '', '_save_checkpoints_secs': 600, '_tf_random_seed': None, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_num_ps_replicas': 0, '_task_id': 0, '_is_chief': True, '_model_dir': 'C:\\Users\\Nick\\AppData\\Local\\Temp\\tmp0zfs791q', '_keep_checkpoint_every_n_hours': 10000, '_task_type': None, '_keep_checkpoint_max': 5}
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:57: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:57: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From f:\anaconda\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\Nick\AppData\Local\Temp\tmp0zfs791q\model.ckpt.
# INFO:tensorflow:loss = 0.701552, step = 1
# INFO:tensorflow:global_step/sec: 7.05466
# INFO:tensorflow:loss = 0.352917, step = 101 (14.181 sec)
# INFO:tensorflow:global_step/sec: 7.14528
# INFO:tensorflow:loss = 0.26697, step = 201 (13.989 sec)
# INFO:tensorflow:global_step/sec: 7.29361
# INFO:tensorflow:loss = 0.190166, step = 301 (13.716 sec)
# INFO:tensorflow:global_step/sec: 7.47569
# INFO:tensorflow:loss = 0.111612, step = 401 (13.372 sec)
# INFO:tensorflow:global_step/sec: 7.58837
# INFO:tensorflow:loss = 0.0740337, step = 501 (13.183 sec)
# INFO:tensorflow:global_step/sec: 7.68246
# INFO:tensorflow:loss = 0.0577181, step = 601 (13.012 sec)
# INFO:tensorflow:global_step/sec: 7.46217
# INFO:tensorflow:loss = 0.0480438, step = 701 (13.401 sec)
# INFO:tensorflow:global_step/sec: 7.58849
# INFO:tensorflow:loss = 0.0442022, step = 801 (13.183 sec)
# INFO:tensorflow:global_step/sec: 7.30047
# INFO:tensorflow:loss = 0.0396925, step = 901 (13.789 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\Nick\AppData\Local\Temp\tmp0zfs791q\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0352019.
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:59: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:59: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From f:\anaconda\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-09-12-19:27:31
# INFO:tensorflow:Restoring parameters from C:\Users\Nick\AppData\Local\Temp\tmp0zfs791q\model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-09-12-19:27:32
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.935065, accuracy/baseline_label_mean = 0.497835, accuracy/threshold_0.500000_mean = 0.935065, auc = 0.969228, auc_precision_recall = 0.952489, global_step = 1000, labels/actual_label_mean = 0.497835, labels/prediction_mean = 0.528264, loss = 0.211506, precision/positive_threshold_0.500000_mean = 0.906504, recall/positive_threshold_0.500000_mean = 0.969565
# Accuracy: 0.935065
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Nick\AppData\Local\Temp\tmp4n5b9vg1
# INFO:tensorflow:Using config: {'_session_config': None, '_environment': 'local', '_num_worker_replicas': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x00000000197C5048>, '_master': '', '_save_checkpoints_secs': 600, '_tf_random_seed': None, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_num_ps_replicas': 0, '_task_id': 0, '_is_chief': True, '_model_dir': 'C:\\Users\\Nick\\AppData\\Local\\Temp\\tmp4n5b9vg1', '_keep_checkpoint_every_n_hours': 10000, '_task_type': None, '_keep_checkpoint_max': 5}
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:57: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:57: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From f:\anaconda\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\Nick\AppData\Local\Temp\tmp4n5b9vg1\model.ckpt.
# INFO:tensorflow:loss = 0.69612, step = 1
# INFO:tensorflow:global_step/sec: 6.80455
# INFO:tensorflow:loss = 0.387889, step = 101 (14.712 sec)
# INFO:tensorflow:global_step/sec: 7.32363
# INFO:tensorflow:loss = 0.30044, step = 201 (13.645 sec)
# INFO:tensorflow:global_step/sec: 7.27971
# INFO:tensorflow:loss = 0.22688, step = 301 (13.746 sec)
# INFO:tensorflow:global_step/sec: 7.54692
# INFO:tensorflow:loss = 0.196163, step = 401 (13.235 sec)
# INFO:tensorflow:global_step/sec: 7.39003
# INFO:tensorflow:loss = 0.10318, step = 501 (13.547 sec)
# INFO:tensorflow:global_step/sec: 7.51966
# INFO:tensorflow:loss = 0.0703605, step = 601 (13.283 sec)
# INFO:tensorflow:global_step/sec: 7.63342
# INFO:tensorflow:loss = 0.0600486, step = 701 (13.100 sec)
# INFO:tensorflow:global_step/sec: 7.53426
# INFO:tensorflow:loss = 0.0506615, step = 801 (13.278 sec)
# INFO:tensorflow:global_step/sec: 7.33603
# INFO:tensorflow:loss = 0.045313, step = 901 (13.673 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\Nick\AppData\Local\Temp\tmp4n5b9vg1\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0428448.
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:59: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:59: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From f:\anaconda\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-09-12-19:30:09
# INFO:tensorflow:Restoring parameters from C:\Users\Nick\AppData\Local\Temp\tmp4n5b9vg1\model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-09-12-19:30:10
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.911255, accuracy/baseline_label_mean = 0.493506, accuracy/threshold_0.500000_mean = 0.911255, auc = 0.958333, auc_precision_recall = 0.935761, global_step = 1000, labels/actual_label_mean = 0.493506, labels/prediction_mean = 0.543998, loss = 0.269742, precision/positive_threshold_0.500000_mean = 0.866667, recall/positive_threshold_0.500000_mean = 0.969298
# Accuracy: 0.911255
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Nick\AppData\Local\Temp\tmp5ry39h0v
# INFO:tensorflow:Using config: {'_session_config': None, '_environment': 'local', '_num_worker_replicas': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000000016C7C198>, '_master': '', '_save_checkpoints_secs': 600, '_tf_random_seed': None, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_num_ps_replicas': 0, '_task_id': 0, '_is_chief': True, '_model_dir': 'C:\\Users\\Nick\\AppData\\Local\\Temp\\tmp5ry39h0v', '_keep_checkpoint_every_n_hours': 10000, '_task_type': None, '_keep_checkpoint_max': 5}
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:57: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-6-3420bd7a3951>:57: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From f:\anaconda\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\Nick\AppData\Local\Temp\tmp5ry39h0v\model.ckpt.
# INFO:tensorflow:loss = 0.693795, step = 1
# INFO:tensorflow:global_step/sec: 6.60224
# INFO:tensorflow:loss = 0.361335, step = 101 (15.141 sec)
# INFO:tensorflow:global_step/sec: 6.48853
# INFO:tensorflow:loss = 0.258771, step = 201 (15.406 sec)

# %% [markdown]
# ### Stores Output into csv file.

# %%
outputFile = 'results.csv'

with open(outputFile, 'w') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(accuracy_dict.keys())
    writer.writerows(zip(*accuracy_dict.values()))
